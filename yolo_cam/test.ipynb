# %%
import cv2

cap = cv2.VideoCapture("20251001222430_8690.dav")
while True:
    ret, frame = cap.read()
    print(frame.shape)
# Out:
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# (1440, 2560, 3)
# ...
